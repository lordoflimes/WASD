# %% [markdown]
# # WASD: Wireless Anomaly Signal Dataset
#
# * Authors: Jinha Kim (jinha.kim@o.cnu.ac.kr), Hyeongwoo Kim (Hyeongwoo.kim@o.cnu.ac.kr), Byungkwan Kim(byungkwan.kim@cnu.ac.kr)
#
# * Version: 2024.10.21

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### Data Loader for IQ Data

# %%
bin_dir = './IQ_Data/27_LTE_1/bin/IQ_2024-04-19T15-31-17_743444552.bin'

bin_data = np.fromfile(bin_dir, 'int32')
bin_data = bin_data[::2] + 1j*bin_data[1::2]

plt.title('IQ Data')
plt.plot(bin_data.real)
plt.plot(bin_data.imag)
plt.show()

# %% [markdown]
# ### Data Loader for Spectrogram (NPY) Data

# %%
DIR_TRAIN = './npy data/Abnormal/Abnormal_spectrogram.npy'

input_size = 400
img_data = np.memmap(DIR_TRAIN, dtype=np.uint16, mode='r+')
img_data = np.reshape(img_data,(-1,input_size,input_size))

plt.title('STFT Data')
plt.imshow(img_data[0,:,:])
plt.show()

# %% [markdown]
# ### Data Loader for Label (CSV) Data

# %%
df = pd.read_csv('./npy data/Abnormal/label/Spectrum_label.csv')

print(df)
# Out:
#        Unnamed: 0      band                              image id  image name  \
# 0               0  27_LTE_1  IQ_2024-07-24T21-31-00_397482081.bin           0
# 1               1  27_LTE_1  IQ_2024-07-24T21-31-03_809262439.bin           1
# 2               2  27_LTE_1  IQ_2024-07-24T21-31-07_366276780.bin           2
# 3               3  27_LTE_1  IQ_2024-07-24T21-31-07_366276780.bin           2
# 4               4  27_LTE_1  IQ_2024-07-24T21-31-10_779570802.bin           3
# ...           ...       ...                                   ...         ...
# 14245       16644   51_5G_7  IQ_2024-07-15T21-14-49_124833956.bin        9494
# 14246       16646   51_5G_7   IQ_2024-07-15T21-14-56_55697155.bin        9496
# 14247       16647   51_5G_7  IQ_2024-07-15T21-14-59_460586607.bin        9497
# 14248       16648   51_5G_7  IQ_2024-07-15T21-15-02_886740752.bin        9498
# 14249       16649   51_5G_7  IQ_2024-07-15T21-15-06_441094072.bin        9499
#
#        signal id        x       y       w       h  SNR
# 0              1   57.625  253.00  15.375  141.25  -10
# 1              2  245.125   88.00  28.250   95.00  -10
# 2              0  355.625  241.50  14.000  160.25  -10
# 3              2  338.750  157.50  17.000  111.25  -10
# 4              2  130.625  204.75  35.250  152.75  -10
# ...          ...      ...     ...     ...     ...  ...
# 14245          2  203.500   51.75  70.000  168.00  -10
# 14246          0  231.875    0.00  14.000  404.00  -10
# 14247          2  306.000  216.50  19.750   53.00  -10
# 14248          2   53.125  124.50  22.625   67.75  -10
# 14249          2  144.750  260.75  39.500   92.25  -10
#
# [14250 rows x 10 columns]
